# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/cifar/cifar-10-python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [00:31, 5.46MB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    data = np.array(x)
    return data/data.max()



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
from sklearn.preprocessing import LabelBinarizer
encoder = LabelBinarizer()
encoder.fit(range(10))

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    return encoder.transform(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=(None, image_shape[0], image_shape[1],image_shape[2]), name="x")


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=(None, n_classes), name="y")


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    canal = int(x_tensor.shape[3])
    
    weigth = tf.Variable(tf.truncated_normal([conv_ksize[0], conv_ksize[1], canal,conv_num_outputs]))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    strides = [1, conv_strides[0], conv_strides[1],1]
    conv_layer = tf.nn.conv2d(x_tensor,weigth, strides=strides, padding='SAME')
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    conv_layer = tf.nn.relu(conv_layer)
    
    ksize_pool = [1, pool_ksize[0], pool_ksize[1],1]
    strides_pool = [1, pool_strides[0], pool_strides[1],1]
    conv_layer = tf.nn.max_pool(
        conv_layer,
        ksize=ksize_pool,
        strides=strides_pool,
        padding="SAME"
    )
    return conv_layer 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    dados = x_tensor.get_shape().as_list()
    print(dados)
    batch = dados[0]
    altura = dados[1]
    largura = dados[2]
    profundidade = dados[3]
    '''
    Para se ter o tamnho total da imagem(em seus 3 canais) no fomato achatado multiplica-se
    suas dimensoes, para reformular seu formato deve ser usado a funcao tf.reshape(),
    ao passar o tamanho -1, especifica que o formato de saido serpa achatado(Flattened)
    '''
    novo_tamanho = int(profundidade * altura * largura)
    
    return tf.reshape(x_tensor,shape=[-1, novo_tamanho])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# [None, 10, 30, 6]
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    num_entradas = x_tensor.get_shape().as_list()[1]
    weight = tf.Variable(tf.random_uniform([num_entradas, num_outputs], -0.01, 0.01))
    bias = tf.Variable(tf.zeros(num_outputs))
    
    rede = tf.add(tf.matmul(x_tensor,weight), bias)
    rede = tf.nn.relu(rede)
    return rede


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    num_entradas = x_tensor.get_shape().as_list()[1]
    weight = tf.Variable(tf.random_uniform([num_entradas, num_outputs], -0.01, 0.01))
    bias = tf.Variable(tf.zeros(num_outputs))
    rede = tf.add(tf.matmul(x_tensor,weight), bias)
    return rede


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    print(x, keep_prob)
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    ######
    #Camadas a serem modeladas(32x32x3),(16x16x48),(8x8x192),(4x4x384),(2x2x512)
    conv_ksize = (3,3)
    conv_strides = (2,2)
    pool_ksize = (2,2)
    pool_strides = (1,1)
    
    #(32x32x3)=>(16x16x48)
    rede = conv2d_maxpool(x,64,conv_ksize,conv_strides, pool_ksize, pool_strides)
    
    #(16x16x48)=>(8x8x256)    
    conv_ksize = (2,2)
    rede = conv2d_maxpool(x,128,conv_ksize,conv_strides, pool_ksize, pool_strides)    
        
    #(4x4x384)=>(2x2x512)    
    pool_ksize = (1,1)
    rede = conv2d_maxpool(x,512,conv_ksize,conv_strides, pool_ksize, pool_strides)
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    
    #(2x2x512)=>(?,2048)
    rede = flatten(rede)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    
    rede_full = tf.nn.dropout(rede, keep_prob)
    
    rede_full = fully_conn(rede_full,512)
    rede_full = fully_conn(rede_full,128)
    rede_full = fully_conn(rede_full,64)
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    saida = output(rede_full,10)
    
    
    # TODO: return output
    return saida


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Tensor("x:0", shape=(?, 32, 32, 3), dtype=float32) Tensor("keep_prob:0", dtype=float32)
# [None, 16, 16, 512]
# Tensor("Placeholder:0", shape=(?, 32, 32, 3), dtype=float32) Tensor("Placeholder_1:0", dtype=float32)
# [None, 16, 16, 512]
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    session.run(optimizer, feed_dict={
        x: feature_batch,
        y: label_batch,
        keep_prob: keep_probability
    })
        
    pass


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    perda = session.run(cost, feed_dict={
        x:feature_batch,
        y:label_batch,
        keep_prob: 1.
    })
    validacao = session.run(accuracy, feed_dict={
        x:valid_features,
        y:valid_labels,
        keep_prob: 1.
    })
    
    print('Perda: {:>10.4f} | Acuracia: {:.4f}'.format(
        perda,
        validacao))
    pass

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 75
batch_size = 256
keep_probability = 0.25

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Perda:     2.2613 | Acuracia: 0.1920
# Epoch  2, CIFAR-10 Batch 1:  Perda:     2.1632 | Acuracia: 0.2462
# Epoch  3, CIFAR-10 Batch 1:  Perda:     2.0199 | Acuracia: 0.2864
# Epoch  4, CIFAR-10 Batch 1:  Perda:     1.8427 | Acuracia: 0.3350
# Epoch  5, CIFAR-10 Batch 1:  Perda:     1.7226 | Acuracia: 0.3612
# Epoch  6, CIFAR-10 Batch 1:  Perda:     1.6414 | Acuracia: 0.3882
# Epoch  7, CIFAR-10 Batch 1:  Perda:     1.5485 | Acuracia: 0.3982
# Epoch  8, CIFAR-10 Batch 1:  Perda:     1.3881 | Acuracia: 0.4188
# Epoch  9, CIFAR-10 Batch 1:  Perda:     1.2312 | Acuracia: 0.4198
# Epoch 10, CIFAR-10 Batch 1:  Perda:     1.0158 | Acuracia: 0.4428
# Epoch 11, CIFAR-10 Batch 1:  Perda:     0.8865 | Acuracia: 0.4528
# Epoch 12, CIFAR-10 Batch 1:  Perda:     0.8124 | Acuracia: 0.4732
# Epoch 13, CIFAR-10 Batch 1:  Perda:     0.7144 | Acuracia: 0.4684
# Epoch 14, CIFAR-10 Batch 1:  Perda:     0.7282 | Acuracia: 0.4754
# Epoch 15, CIFAR-10 Batch 1:  Perda:     0.6267 | Acuracia: 0.4780
# Epoch 16, CIFAR-10 Batch 1:  Perda:     0.6776 | Acuracia: 0.4562
# Epoch 17, CIFAR-10 Batch 1:  Perda:     0.6129 | Acuracia: 0.4808
# Epoch 18, CIFAR-10 Batch 1:  Perda:     0.4574 | Acuracia: 0.5074
# Epoch 19, CIFAR-10 Batch 1:  Perda:     0.4045 | Acuracia: 0.5036
# Epoch 20, CIFAR-10 Batch 1:  Perda:     0.3346 | Acuracia: 0.5118
# Epoch 21, CIFAR-10 Batch 1:  Perda:     0.3091 | Acuracia: 0.5042
# Epoch 22, CIFAR-10 Batch 1:  Perda:     0.2661 | Acuracia: 0.5042
# Epoch 23, CIFAR-10 Batch 1:  Perda:     0.2210 | Acuracia: 0.4928
# Epoch 24, CIFAR-10 Batch 1:  Perda:     0.2117 | Acuracia: 0.4670
# Epoch 25, CIFAR-10 Batch 1:  Perda:     0.1473 | Acuracia: 0.5058
# Epoch 26, CIFAR-10 Batch 1:  Perda:     0.1141 | Acuracia: 0.5074
# Epoch 27, CIFAR-10 Batch 1:  Perda:     0.1064 | Acuracia: 0.4926
# Epoch 28, CIFAR-10 Batch 1:  Perda:     0.0865 | Acuracia: 0.5096
# Epoch 29, CIFAR-10 Batch 1:  Perda:     0.0714 | Acuracia: 0.5216
# Epoch 30, CIFAR-10 Batch 1:  Perda:     0.0639 | Acuracia: 0.5100
# Epoch 31, CIFAR-10 Batch 1:  Perda:     0.0437 | Acuracia: 0.5198
# Epoch 32, CIFAR-10 Batch 1:  Perda:     0.0339 | Acuracia: 0.5162
# Epoch 33, CIFAR-10 Batch 1:  Perda:     0.0370 | Acuracia: 0.4948
# Epoch 34, CIFAR-10 Batch 1:  Perda:     0.0328 | Acuracia: 0.4782
# Epoch 35, CIFAR-10 Batch 1:  Perda:     0.0221 | Acuracia: 0.5170
# Epoch 36, CIFAR-10 Batch 1:  Perda:     0.0084 | Acuracia: 0.5188
# Epoch 37, CIFAR-10 Batch 1:  Perda:     0.0101 | Acuracia: 0.5194
# Epoch 38, CIFAR-10 Batch 1:  Perda:     0.0090 | Acuracia: 0.5070
# Epoch 39, CIFAR-10 Batch 1:  Perda:     0.0101 | Acuracia: 0.4994
# Epoch 40, CIFAR-10 Batch 1:  Perda:     0.0088 | Acuracia: 0.5156
# Epoch 41, CIFAR-10 Batch 1:  Perda:     0.0088 | Acuracia: 0.5088
# Epoch 42, CIFAR-10 Batch 1:  Perda:     0.0080 | Acuracia: 0.5028
# Epoch 43, CIFAR-10 Batch 1:  Perda:     0.0085 | Acuracia: 0.4732
# Epoch 44, CIFAR-10 Batch 1:  Perda:     0.0038 | Acuracia: 0.4918
# Epoch 45, CIFAR-10 Batch 1:  Perda:     0.0040 | Acuracia: 0.5032
# Epoch 46, CIFAR-10 Batch 1:  Perda:     0.0024 | Acuracia: 0.5126
# Epoch 47, CIFAR-10 Batch 1:  Perda:     0.0024 | Acuracia: 0.5044
# Epoch 48, CIFAR-10 Batch 1:  Perda:     0.0014 | Acuracia: 0.5000
# Epoch 49, CIFAR-10 Batch 1:  Perda:     0.0015 | Acuracia: 0.5206
# Epoch 50, CIFAR-10 Batch 1:  Perda:     0.0013 | Acuracia: 0.5102
# Epoch 51, CIFAR-10 Batch 1:  Perda:     0.0008 | Acuracia: 0.5182
# Epoch 52, CIFAR-10 Batch 1:  Perda:     0.0010 | Acuracia: 0.5154
# Epoch 53, CIFAR-10 Batch 1:  Perda:     0.0005 | Acuracia: 0.5246
# Epoch 54, CIFAR-10 Batch 1:  Perda:     0.0003 | Acuracia: 0.5272
# Epoch 55, CIFAR-10 Batch 1:  Perda:     0.0003 | Acuracia: 0.5258
# Epoch 56, CIFAR-10 Batch 1:  Perda:     0.0003 | Acuracia: 0.5242
# Epoch 57, CIFAR-10 Batch 1:  Perda:     0.0002 | Acuracia: 0.5144
# Epoch 58, CIFAR-10 Batch 1:  Perda:     0.0002 | Acuracia: 0.5236
# Epoch 59, CIFAR-10 Batch 1:  Perda:     0.0002 | Acuracia: 0.5144
# Epoch 60, CIFAR-10 Batch 1:  Perda:     0.0001 | Acuracia: 0.5160
# Epoch 61, CIFAR-10 Batch 1:  Perda:     0.0003 | Acuracia: 0.5174
# Epoch 62, CIFAR-10 Batch 1:  Perda:     0.0003 | Acuracia: 0.5216
# Epoch 63, CIFAR-10 Batch 1:  Perda:     0.0002 | Acuracia: 0.5236
# Epoch 64, CIFAR-10 Batch 1:  Perda:     0.0002 | Acuracia: 0.5120
# Epoch 65, CIFAR-10 Batch 1:  Perda:     0.0001 | Acuracia: 0.5162
# Epoch 66, CIFAR-10 Batch 1:  Perda:     0.0002 | Acuracia: 0.5160
# Epoch 67, CIFAR-10 Batch 1:  Perda:     0.0001 | Acuracia: 0.5196
# Epoch 68, CIFAR-10 Batch 1:  Perda:     0.0003 | Acuracia: 0.5148
# Epoch 69, CIFAR-10 Batch 1:  Perda:     0.0001 | Acuracia: 0.5200
# Epoch 70, CIFAR-10 Batch 1:  Perda:     0.0005 | Acuracia: 0.5220
# Epoch 71, CIFAR-10 Batch 1:  Perda:     0.0002 | Acuracia: 0.5084
# Epoch 72, CIFAR-10 Batch 1:  Perda:     0.0001 | Acuracia: 0.5190
# Epoch 73, CIFAR-10 Batch 1:  Perda:     0.0000 | Acuracia: 0.5236
# Epoch 74, CIFAR-10 Batch 1:  Perda:     0.0001 | Acuracia: 0.5198
# Epoch 75, CIFAR-10 Batch 1:  Perda:     0.0000 | Acuracia: 0.5156

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Perda:     2.2713 | Acuracia: 0.2018
# Epoch  1, CIFAR-10 Batch 2:  Perda:     1.9766 | Acuracia: 0.2212
# Epoch  1, CIFAR-10 Batch 3:  Perda:     1.6556 | Acuracia: 0.2594
# Epoch  1, CIFAR-10 Batch 4:  Perda:     1.7962 | Acuracia: 0.3056
# Epoch  1, CIFAR-10 Batch 5:  Perda:     1.6810 | Acuracia: 0.3558
# Epoch  2, CIFAR-10 Batch 1:  Perda:     2.0055 | Acuracia: 0.3818
# Epoch  2, CIFAR-10 Batch 2:  Perda:     1.4231 | Acuracia: 0.3854
# Epoch  2, CIFAR-10 Batch 3:  Perda:     1.3747 | Acuracia: 0.3940
# Epoch  2, CIFAR-10 Batch 4:  Perda:     1.4073 | Acuracia: 0.4306
# Epoch  2, CIFAR-10 Batch 5:  Perda:     1.4409 | Acuracia: 0.4362
# Epoch  3, CIFAR-10 Batch 1:  Perda:     1.6316 | Acuracia: 0.4474
# Epoch  3, CIFAR-10 Batch 2:  Perda:     1.1223 | Acuracia: 0.4362
# Epoch  3, CIFAR-10 Batch 3:  Perda:     1.0684 | Acuracia: 0.4590
# Epoch  3, CIFAR-10 Batch 4:  Perda:     1.2053 | Acuracia: 0.4836
# Epoch  3, CIFAR-10 Batch 5:  Perda:     1.2166 | Acuracia: 0.4930
# Epoch  4, CIFAR-10 Batch 1:  Perda:     1.3624 | Acuracia: 0.5040
# Epoch  4, CIFAR-10 Batch 2:  Perda:     0.9111 | Acuracia: 0.4764
# Epoch  4, CIFAR-10 Batch 3:  Perda:     0.8789 | Acuracia: 0.4938
# Epoch  4, CIFAR-10 Batch 4:  Perda:     0.9263 | Acuracia: 0.5162
# Epoch  4, CIFAR-10 Batch 5:  Perda:     1.0184 | Acuracia: 0.5324
# Epoch  5, CIFAR-10 Batch 1:  Perda:     1.0680 | Acuracia: 0.5168
# Epoch  5, CIFAR-10 Batch 2:  Perda:     0.7170 | Acuracia: 0.5204
# Epoch  5, CIFAR-10 Batch 3:  Perda:     0.7114 | Acuracia: 0.5362
# Epoch  5, CIFAR-10 Batch 4:  Perda:     0.7735 | Acuracia: 0.5510
# Epoch  5, CIFAR-10 Batch 5:  Perda:     0.7383 | Acuracia: 0.5498
# Epoch  6, CIFAR-10 Batch 1:  Perda:     0.8872 | Acuracia: 0.5500
# Epoch  6, CIFAR-10 Batch 2:  Perda:     0.5315 | Acuracia: 0.5600
# Epoch  6, CIFAR-10 Batch 3:  Perda:     0.4924 | Acuracia: 0.5558
# Epoch  6, CIFAR-10 Batch 4:  Perda:     0.6444 | Acuracia: 0.5654
# Epoch  6, CIFAR-10 Batch 5:  Perda:     0.5378 | Acuracia: 0.5774
# Epoch  7, CIFAR-10 Batch 1:  Perda:     0.6638 | Acuracia: 0.5674
# Epoch  7, CIFAR-10 Batch 2:  Perda:     0.3871 | Acuracia: 0.5780
# Epoch  7, CIFAR-10 Batch 3:  Perda:     0.3642 | Acuracia: 0.5710
# Epoch  7, CIFAR-10 Batch 4:  Perda:     0.5040 | Acuracia: 0.5898
# Epoch  7, CIFAR-10 Batch 5:  Perda:     0.3927 | Acuracia: 0.5912
# Epoch  8, CIFAR-10 Batch 1:  Perda:     0.5363 | Acuracia: 0.5834
# Epoch  8, CIFAR-10 Batch 2:  Perda:     0.2830 | Acuracia: 0.5836
# Epoch  8, CIFAR-10 Batch 3:  Perda:     0.2785 | Acuracia: 0.5856
# Epoch  8, CIFAR-10 Batch 4:  Perda:     0.3966 | Acuracia: 0.5920
# Epoch  8, CIFAR-10 Batch 5:  Perda:     0.2918 | Acuracia: 0.6026
# Epoch  9, CIFAR-10 Batch 1:  Perda:     0.4255 | Acuracia: 0.5962
# Epoch  9, CIFAR-10 Batch 2:  Perda:     0.1988 | Acuracia: 0.5930
# Epoch  9, CIFAR-10 Batch 3:  Perda:     0.2270 | Acuracia: 0.5892
# Epoch  9, CIFAR-10 Batch 4:  Perda:     0.2739 | Acuracia: 0.5982
# Epoch  9, CIFAR-10 Batch 5:  Perda:     0.2236 | Acuracia: 0.6096
# Epoch 10, CIFAR-10 Batch 1:  Perda:     0.2831 | Acuracia: 0.5980
# Epoch 10, CIFAR-10 Batch 2:  Perda:     0.1353 | Acuracia: 0.6000
# Epoch 10, CIFAR-10 Batch 3:  Perda:     0.1637 | Acuracia: 0.6034
# Epoch 10, CIFAR-10 Batch 4:  Perda:     0.1767 | Acuracia: 0.5968
# Epoch 10, CIFAR-10 Batch 5:  Perda:     0.1614 | Acuracia: 0.6112
# Epoch 11, CIFAR-10 Batch 1:  Perda:     0.1987 | Acuracia: 0.5944
# Epoch 11, CIFAR-10 Batch 2:  Perda:     0.0985 | Acuracia: 0.5732
# Epoch 11, CIFAR-10 Batch 3:  Perda:     0.1183 | Acuracia: 0.6060
# Epoch 11, CIFAR-10 Batch 4:  Perda:     0.1055 | Acuracia: 0.6072
# Epoch 11, CIFAR-10 Batch 5:  Perda:     0.1141 | Acuracia: 0.6222
# Epoch 12, CIFAR-10 Batch 1:  Perda:     0.1473 | Acuracia: 0.5964
# Epoch 12, CIFAR-10 Batch 2:  Perda:     0.0631 | Acuracia: 0.5862
# Epoch 12, CIFAR-10 Batch 3:  Perda:     0.0826 | Acuracia: 0.6068
# Epoch 12, CIFAR-10 Batch 4:  Perda:     0.0664 | Acuracia: 0.6118
# Epoch 12, CIFAR-10 Batch 5:  Perda:     0.0694 | Acuracia: 0.6154
# Epoch 13, CIFAR-10 Batch 1:  Perda:     0.1067 | Acuracia: 0.6040
# Epoch 13, CIFAR-10 Batch 2:  Perda:     0.0628 | Acuracia: 0.5966
# Epoch 13, CIFAR-10 Batch 3:  Perda:     0.0449 | Acuracia: 0.6136
# Epoch 13, CIFAR-10 Batch 4:  Perda:     0.0618 | Acuracia: 0.6010
# Epoch 13, CIFAR-10 Batch 5:  Perda:     0.0522 | Acuracia: 0.6118
# Epoch 14, CIFAR-10 Batch 1:  Perda:     0.0759 | Acuracia: 0.6026
# Epoch 14, CIFAR-10 Batch 2:  Perda:     0.0480 | Acuracia: 0.5952
# Epoch 14, CIFAR-10 Batch 3:  Perda:     0.0387 | Acuracia: 0.6090
# Epoch 14, CIFAR-10 Batch 4:  Perda:     0.0474 | Acuracia: 0.5910
# Epoch 14, CIFAR-10 Batch 5:  Perda:     0.0481 | Acuracia: 0.6094
# Epoch 15, CIFAR-10 Batch 1:  Perda:     0.0479 | Acuracia: 0.6106
# Epoch 15, CIFAR-10 Batch 2:  Perda:     0.0386 | Acuracia: 0.5894
# Epoch 15, CIFAR-10 Batch 3:  Perda:     0.0326 | Acuracia: 0.6080
# Epoch 15, CIFAR-10 Batch 4:  Perda:     0.0429 | Acuracia: 0.5954
# Epoch 15, CIFAR-10 Batch 5:  Perda:     0.0402 | Acuracia: 0.6098
# Epoch 16, CIFAR-10 Batch 1:  Perda:     0.0373 | Acuracia: 0.6052
# Epoch 16, CIFAR-10 Batch 2:  Perda:     0.0244 | Acuracia: 0.6002
# Epoch 16, CIFAR-10 Batch 3:  Perda:     0.0234 | Acuracia: 0.5982
# Epoch 16, CIFAR-10 Batch 4:  Perda:     0.0389 | Acuracia: 0.5914
# Epoch 16, CIFAR-10 Batch 5:  Perda:     0.0277 | Acuracia: 0.6040
# Epoch 17, CIFAR-10 Batch 1:  Perda:     0.0215 | Acuracia: 0.6066
# Epoch 17, CIFAR-10 Batch 2:  Perda:     0.0135 | Acuracia: 0.5986
# Epoch 17, CIFAR-10 Batch 3:  Perda:     0.0164 | Acuracia: 0.6066
# Epoch 17, CIFAR-10 Batch 4:  Perda:     0.0211 | Acuracia: 0.6014
# Epoch 17, CIFAR-10 Batch 5:  Perda:     0.0273 | Acuracia: 0.6070
# Epoch 18, CIFAR-10 Batch 1:  Perda:     0.0145 | Acuracia: 0.6078
# Epoch 18, CIFAR-10 Batch 2:  Perda:     0.0121 | Acuracia: 0.5940
# Epoch 18, CIFAR-10 Batch 3:  Perda:     0.0113 | Acuracia: 0.6068
# Epoch 18, CIFAR-10 Batch 4:  Perda:     0.0100 | Acuracia: 0.6084
# Epoch 18, CIFAR-10 Batch 5:  Perda:     0.0189 | Acuracia: 0.6060
# Epoch 19, CIFAR-10 Batch 1:  Perda:     0.0261 | Acuracia: 0.5956
# Epoch 19, CIFAR-10 Batch 2:  Perda:     0.0173 | Acuracia: 0.5932
# Epoch 19, CIFAR-10 Batch 3:  Perda:     0.0062 | Acuracia: 0.6070
# Epoch 19, CIFAR-10 Batch 4:  Perda:     0.0179 | Acuracia: 0.6006
# Epoch 19, CIFAR-10 Batch 5:  Perda:     0.0089 | Acuracia: 0.6076
# Epoch 20, CIFAR-10 Batch 1:  Perda:     0.0135 | Acuracia: 0.6056
# Epoch 20, CIFAR-10 Batch 2:  Perda:     0.0106 | Acuracia: 0.6034
# Epoch 20, CIFAR-10 Batch 3:  Perda:     0.0068 | Acuracia: 0.6094
# Epoch 20, CIFAR-10 Batch 4:  Perda:     0.0099 | Acuracia: 0.5980
# Epoch 20, CIFAR-10 Batch 5:  Perda:     0.0120 | Acuracia: 0.5876
# Epoch 21, CIFAR-10 Batch 1:  Perda:     0.0116 | Acuracia: 0.5976
# Epoch 21, CIFAR-10 Batch 2:  Perda:     0.0036 | Acuracia: 0.6084
# Epoch 21, CIFAR-10 Batch 3:  Perda:     0.0038 | Acuracia: 0.6162
# Epoch 21, CIFAR-10 Batch 4:  Perda:     0.0097 | Acuracia: 0.6020
# Epoch 21, CIFAR-10 Batch 5:  Perda:     0.0052 | Acuracia: 0.6062
# Epoch 22, CIFAR-10 Batch 1:  Perda:     0.0081 | Acuracia: 0.5918
# Epoch 22, CIFAR-10 Batch 2:  Perda:     0.0045 | Acuracia: 0.6044
# Epoch 22, CIFAR-10 Batch 3:  Perda:     0.0038 | Acuracia: 0.6138
# Epoch 22, CIFAR-10 Batch 4:  Perda:     0.0082 | Acuracia: 0.5994
# Epoch 22, CIFAR-10 Batch 5:  Perda:     0.0066 | Acuracia: 0.5900
# Epoch 23, CIFAR-10 Batch 1:  Perda:     0.0077 | Acuracia: 0.5736
# Epoch 23, CIFAR-10 Batch 2:  Perda:     0.0021 | Acuracia: 0.6078
# Epoch 23, CIFAR-10 Batch 3:  Perda:     0.0040 | Acuracia: 0.6072
# Epoch 23, CIFAR-10 Batch 4:  Perda:     0.0036 | Acuracia: 0.6076
# Epoch 23, CIFAR-10 Batch 5:  Perda:     0.0038 | Acuracia: 0.6068
# Epoch 24, CIFAR-10 Batch 1:  Perda:     0.0035 | Acuracia: 0.5798
# Epoch 24, CIFAR-10 Batch 2:  Perda:     0.0035 | Acuracia: 0.5988
# Epoch 24, CIFAR-10 Batch 3:  Perda:     0.0023 | Acuracia: 0.6054
# Epoch 24, CIFAR-10 Batch 4:  Perda:     0.0047 | Acuracia: 0.5962
# Epoch 24, CIFAR-10 Batch 5:  Perda:     0.0046 | Acuracia: 0.6096
# Epoch 25, CIFAR-10 Batch 1:  Perda:     0.0008 | Acuracia: 0.5934
# Epoch 25, CIFAR-10 Batch 2:  Perda:     0.0019 | Acuracia: 0.6056
# Epoch 25, CIFAR-10 Batch 3:  Perda:     0.0019 | Acuracia: 0.6074
# Epoch 25, CIFAR-10 Batch 4:  Perda:     0.0046 | Acuracia: 0.5898
# Epoch 25, CIFAR-10 Batch 5:  Perda:     0.0088 | Acuracia: 0.6158
# Epoch 26, CIFAR-10 Batch 1:  Perda:     0.0034 | Acuracia: 0.6046
# Epoch 26, CIFAR-10 Batch 2:  Perda:     0.0018 | Acuracia: 0.6034
# Epoch 26, CIFAR-10 Batch 3:  Perda:     0.0023 | Acuracia: 0.6102
# Epoch 26, CIFAR-10 Batch 4:  Perda:     0.0044 | Acuracia: 0.6040
# Epoch 26, CIFAR-10 Batch 5:  Perda:     0.0033 | Acuracia: 0.6124
# Epoch 27, CIFAR-10 Batch 1:  Perda:     0.0016 | Acuracia: 0.6058
# Epoch 27, CIFAR-10 Batch 2:  Perda:     0.0006 | Acuracia: 0.6120
# Epoch 27, CIFAR-10 Batch 3:  Perda:     0.0005 | Acuracia: 0.6134
# Epoch 27, CIFAR-10 Batch 4:  Perda:     0.0033 | Acuracia: 0.5888
# Epoch 27, CIFAR-10 Batch 5:  Perda:     0.0020 | Acuracia: 0.6066
# Epoch 28, CIFAR-10 Batch 1:  Perda:     0.0016 | Acuracia: 0.6144
# Epoch 28, CIFAR-10 Batch 2:  Perda:     0.0016 | Acuracia: 0.6056
# Epoch 28, CIFAR-10 Batch 3:  Perda:     0.0008 | Acuracia: 0.6128
# Epoch 28, CIFAR-10 Batch 4:  Perda:     0.0031 | Acuracia: 0.5930
# Epoch 28, CIFAR-10 Batch 5:  Perda:     0.0031 | Acuracia: 0.6090
# Epoch 29, CIFAR-10 Batch 1:  Perda:     0.0013 | Acuracia: 0.6088
# Epoch 29, CIFAR-10 Batch 2:  Perda:     0.0009 | Acuracia: 0.6084
# Epoch 29, CIFAR-10 Batch 3:  Perda:     0.0007 | Acuracia: 0.6148
# Epoch 29, CIFAR-10 Batch 4:  Perda:     0.0014 | Acuracia: 0.6010
# Epoch 29, CIFAR-10 Batch 5:  Perda:     0.0037 | Acuracia: 0.6052
# Epoch 30, CIFAR-10 Batch 1:  Perda:     0.0015 | Acuracia: 0.6048
# Epoch 30, CIFAR-10 Batch 2:  Perda:     0.0013 | Acuracia: 0.6052
# Epoch 30, CIFAR-10 Batch 3:  Perda:     0.0019 | Acuracia: 0.6124
# Epoch 30, CIFAR-10 Batch 4:  Perda:     0.0074 | Acuracia: 0.5876
# Epoch 30, CIFAR-10 Batch 5:  Perda:     0.0024 | Acuracia: 0.5976
# Epoch 31, CIFAR-10 Batch 1:  Perda:     0.0011 | Acuracia: 0.6014
# Epoch 31, CIFAR-10 Batch 2:  Perda:     0.0016 | Acuracia: 0.6090
# Epoch 31, CIFAR-10 Batch 3:  Perda:     0.0004 | Acuracia: 0.6160
# Epoch 31, CIFAR-10 Batch 4:  Perda:     0.0008 | Acuracia: 0.6064
# Epoch 31, CIFAR-10 Batch 5:  Perda:     0.0026 | Acuracia: 0.6066
# Epoch 32, CIFAR-10 Batch 1:  Perda:     0.0017 | Acuracia: 0.6042
# Epoch 32, CIFAR-10 Batch 2:  Perda:     0.0005 | Acuracia: 0.6094
# Epoch 32, CIFAR-10 Batch 3:  Perda:     0.0005 | Acuracia: 0.6078
# Epoch 32, CIFAR-10 Batch 4:  Perda:     0.0014 | Acuracia: 0.6066
# Epoch 32, CIFAR-10 Batch 5:  Perda:     0.0019 | Acuracia: 0.6070
# Epoch 33, CIFAR-10 Batch 1:  Perda:     0.0006 | Acuracia: 0.6076
# Epoch 33, CIFAR-10 Batch 2:  Perda:     0.0003 | Acuracia: 0.6138
# Epoch 33, CIFAR-10 Batch 3:  Perda:     0.0006 | Acuracia: 0.6044
# Epoch 33, CIFAR-10 Batch 4:  Perda:     0.0006 | Acuracia: 0.6082
# Epoch 33, CIFAR-10 Batch 5:  Perda:     0.0003 | Acuracia: 0.6108
# Epoch 34, CIFAR-10 Batch 1:  Perda:     0.0025 | Acuracia: 0.6076
# Epoch 34, CIFAR-10 Batch 2:  Perda:     0.0002 | Acuracia: 0.6088
# Epoch 34, CIFAR-10 Batch 3:  Perda:     0.0004 | Acuracia: 0.6076
# Epoch 34, CIFAR-10 Batch 4:  Perda:     0.0013 | Acuracia: 0.6014
# Epoch 34, CIFAR-10 Batch 5:  Perda:     0.0007 | Acuracia: 0.6096
# Epoch 35, CIFAR-10 Batch 1:  Perda:     0.0030 | Acuracia: 0.6108
# Epoch 35, CIFAR-10 Batch 2:  Perda:     0.0006 | Acuracia: 0.6092
# Epoch 35, CIFAR-10 Batch 3:  Perda:     0.0002 | Acuracia: 0.6028
# Epoch 35, CIFAR-10 Batch 4:  Perda:     0.0004 | Acuracia: 0.6058
# Epoch 35, CIFAR-10 Batch 5:  Perda:     0.0017 | Acuracia: 0.5966
# Epoch 36, CIFAR-10 Batch 1:  Perda:     0.0010 | Acuracia: 0.6084
# Epoch 36, CIFAR-10 Batch 2:  Perda:     0.0003 | Acuracia: 0.6062
# Epoch 36, CIFAR-10 Batch 3:  Perda:     0.0005 | Acuracia: 0.6012
# Epoch 36, CIFAR-10 Batch 4:  Perda:     0.0004 | Acuracia: 0.6086
# Epoch 36, CIFAR-10 Batch 5:  Perda:     0.0012 | Acuracia: 0.6068
# Epoch 37, CIFAR-10 Batch 1:  Perda:     0.0032 | Acuracia: 0.6078
# Epoch 37, CIFAR-10 Batch 2:  Perda:     0.0002 | Acuracia: 0.6152
# Epoch 37, CIFAR-10 Batch 3:  Perda:     0.0005 | Acuracia: 0.6040
# Epoch 37, CIFAR-10 Batch 4:  Perda:     0.0033 | Acuracia: 0.5988
# Epoch 37, CIFAR-10 Batch 5:  Perda:     0.0005 | Acuracia: 0.6104
# Epoch 38, CIFAR-10 Batch 1:  Perda:     0.0008 | Acuracia: 0.6096
# Epoch 38, CIFAR-10 Batch 2:  Perda:     0.0001 | Acuracia: 0.6038
# Epoch 38, CIFAR-10 Batch 3:  Perda:     0.0008 | Acuracia: 0.6010
# Epoch 38, CIFAR-10 Batch 4:  Perda:     0.0005 | Acuracia: 0.6024
# Epoch 38, CIFAR-10 Batch 5:  Perda:     0.0002 | Acuracia: 0.5976
# Epoch 39, CIFAR-10 Batch 1:  Perda:     0.0020 | Acuracia: 0.6136
# Epoch 39, CIFAR-10 Batch 2:  Perda:     0.0004 | Acuracia: 0.6088
# Epoch 39, CIFAR-10 Batch 3:  Perda:     0.0003 | Acuracia: 0.6118
# Epoch 39, CIFAR-10 Batch 4:  Perda:     0.0010 | Acuracia: 0.6058
# Epoch 39, CIFAR-10 Batch 5:  Perda:     0.0005 | Acuracia: 0.6134
# Epoch 40, CIFAR-10 Batch 1:  Perda:     0.0018 | Acuracia: 0.6080
# Epoch 40, CIFAR-10 Batch 2:  Perda:     0.0007 | Acuracia: 0.6066
# Epoch 40, CIFAR-10 Batch 3:  Perda:     0.0003 | Acuracia: 0.6050
# Epoch 40, CIFAR-10 Batch 4:  Perda:     0.0001 | Acuracia: 0.6052
# Epoch 40, CIFAR-10 Batch 5:  Perda:     0.0005 | Acuracia: 0.6120
# Epoch 41, CIFAR-10 Batch 1:  Perda:     0.0006 | Acuracia: 0.6144
# Epoch 41, CIFAR-10 Batch 2:  Perda:     0.0004 | Acuracia: 0.6014
# Epoch 41, CIFAR-10 Batch 3:  Perda:     0.0001 | Acuracia: 0.6072
# Epoch 41, CIFAR-10 Batch 4:  Perda:     0.0004 | Acuracia: 0.6126
# Epoch 41, CIFAR-10 Batch 5:  Perda:     0.0004 | Acuracia: 0.6082
# Epoch 42, CIFAR-10 Batch 1:  Perda:     0.0010 | Acuracia: 0.6178
# Epoch 42, CIFAR-10 Batch 2:  Perda:     0.0001 | Acuracia: 0.6062
# Epoch 42, CIFAR-10 Batch 3:  Perda:     0.0001 | Acuracia: 0.5958
# Epoch 42, CIFAR-10 Batch 4:  Perda:     0.0012 | Acuracia: 0.6020
# Epoch 42, CIFAR-10 Batch 5:  Perda:     0.0001 | Acuracia: 0.6122
# Epoch 43, CIFAR-10 Batch 1:  Perda:     0.0003 | Acuracia: 0.6078
# Epoch 43, CIFAR-10 Batch 2:  Perda:     0.0001 | Acuracia: 0.6028
# Epoch 43, CIFAR-10 Batch 3:  Perda:     0.0002 | Acuracia: 0.6038
# Epoch 43, CIFAR-10 Batch 4:  Perda:     0.0002 | Acuracia: 0.6022
# Epoch 43, CIFAR-10 Batch 5:  Perda:     0.0005 | Acuracia: 0.6050
# Epoch 44, CIFAR-10 Batch 1:  Perda:     0.0002 | Acuracia: 0.6058
# Epoch 44, CIFAR-10 Batch 2:  Perda:     0.0002 | Acuracia: 0.6086
# Epoch 44, CIFAR-10 Batch 3:  Perda:     0.0001 | Acuracia: 0.5988
# Epoch 44, CIFAR-10 Batch 4:  Perda:     0.0004 | Acuracia: 0.6092
# Epoch 44, CIFAR-10 Batch 5:  Perda:     0.0003 | Acuracia: 0.6102
# Epoch 45, CIFAR-10 Batch 1:  Perda:     0.0007 | Acuracia: 0.6094
# Epoch 45, CIFAR-10 Batch 2:  Perda:     0.0012 | Acuracia: 0.6042
# Epoch 45, CIFAR-10 Batch 3:  Perda:     0.0001 | Acuracia: 0.6032
# Epoch 45, CIFAR-10 Batch 4:  Perda:     0.0002 | Acuracia: 0.6062
# Epoch 45, CIFAR-10 Batch 5:  Perda:     0.0006 | Acuracia: 0.6058
# Epoch 46, CIFAR-10 Batch 1:  Perda:     0.0003 | Acuracia: 0.6130
# Epoch 46, CIFAR-10 Batch 2:  Perda:     0.0005 | Acuracia: 0.6090
# Epoch 46, CIFAR-10 Batch 3:  Perda:     0.0001 | Acuracia: 0.6058
# Epoch 46, CIFAR-10 Batch 4:  Perda:     0.0003 | Acuracia: 0.6090
# Epoch 46, CIFAR-10 Batch 5:  Perda:     0.0008 | Acuracia: 0.6020
# Epoch 47, CIFAR-10 Batch 1:  Perda:     0.0007 | Acuracia: 0.6128
# Epoch 47, CIFAR-10 Batch 2:  Perda:     0.0006 | Acuracia: 0.6096
# Epoch 47, CIFAR-10 Batch 3:  Perda:     0.0002 | Acuracia: 0.6110
# Epoch 47, CIFAR-10 Batch 4:  Perda:     0.0003 | Acuracia: 0.6088
# Epoch 47, CIFAR-10 Batch 5:  Perda:     0.0001 | Acuracia: 0.6096
# Epoch 48, CIFAR-10 Batch 1:  Perda:     0.0012 | Acuracia: 0.6074
# Epoch 48, CIFAR-10 Batch 2:  Perda:     0.0002 | Acuracia: 0.6046
# Epoch 48, CIFAR-10 Batch 3:  Perda:     0.0002 | Acuracia: 0.6072
# Epoch 48, CIFAR-10 Batch 4:  Perda:     0.0001 | Acuracia: 0.6088
# Epoch 48, CIFAR-10 Batch 5:  Perda:     0.0003 | Acuracia: 0.6098
# Epoch 49, CIFAR-10 Batch 1:  Perda:     0.0004 | Acuracia: 0.6094
# Epoch 49, CIFAR-10 Batch 2:  Perda:     0.0001 | Acuracia: 0.6104
# Epoch 49, CIFAR-10 Batch 3:  Perda:     0.0001 | Acuracia: 0.6088
# Epoch 49, CIFAR-10 Batch 4:  Perda:     0.0002 | Acuracia: 0.6106
# Epoch 49, CIFAR-10 Batch 5:  Perda:     0.0001 | Acuracia: 0.6090
# Epoch 50, CIFAR-10 Batch 1:  Perda:     0.0004 | Acuracia: 0.6112
# Epoch 50, CIFAR-10 Batch 2:  Perda:     0.0002 | Acuracia: 0.6156
# Epoch 50, CIFAR-10 Batch 3:  Perda:     0.0001 | Acuracia: 0.6072
# Epoch 50, CIFAR-10 Batch 4:  Perda:     0.0004 | Acuracia: 0.6068
# Epoch 50, CIFAR-10 Batch 5:  Perda:     0.0001 | Acuracia: 0.6116
# Epoch 51, CIFAR-10 Batch 1:  Perda:     0.0001 | Acuracia: 0.6102
# Epoch 51, CIFAR-10 Batch 2:  Perda:     0.0005 | Acuracia: 0.6156
# Epoch 51, CIFAR-10 Batch 3:  Perda:     0.0002 | Acuracia: 0.6052
# Epoch 51, CIFAR-10 Batch 4:  Perda:     0.0002 | Acuracia: 0.6122
# Epoch 51, CIFAR-10 Batch 5:  Perda:     0.0002 | Acuracia: 0.6182
# Epoch 52, CIFAR-10 Batch 1:  Perda:     0.0001 | Acuracia: 0.6168
# Epoch 52, CIFAR-10 Batch 2:  Perda:     0.0007 | Acuracia: 0.6174
# Epoch 52, CIFAR-10 Batch 3:  Perda:     0.0001 | Acuracia: 0.6066
# Epoch 52, CIFAR-10 Batch 4:  Perda:     0.0001 | Acuracia: 0.6016
# Epoch 52, CIFAR-10 Batch 5:  Perda:     0.0002 | Acuracia: 0.6124
# Epoch 53, CIFAR-10 Batch 1:  Perda:     0.0012 | Acuracia: 0.6120
# Epoch 53, CIFAR-10 Batch 2:  Perda:     0.0008 | Acuracia: 0.6120
# Epoch 53, CIFAR-10 Batch 3:  Perda:     0.0001 | Acuracia: 0.6048
# Epoch 53, CIFAR-10 Batch 4:  Perda:     0.0003 | Acuracia: 0.6062
# Epoch 53, CIFAR-10 Batch 5:  Perda:     0.0004 | Acuracia: 0.6054
# Epoch 54, CIFAR-10 Batch 1:  Perda:     0.0001 | Acuracia: 0.6118
# Epoch 54, CIFAR-10 Batch 2:  Perda:     0.0005 | Acuracia: 0.6196
# Epoch 54, CIFAR-10 Batch 3:  Perda:     0.0001 | Acuracia: 0.6078
# Epoch 54, CIFAR-10 Batch 4:  Perda:     0.0002 | Acuracia: 0.6026
# Epoch 54, CIFAR-10 Batch 5:  Perda:     0.0003 | Acuracia: 0.6132
# Epoch 55, CIFAR-10 Batch 1:  Perda:     0.0004 | Acuracia: 0.6118
# Epoch 55, CIFAR-10 Batch 2:  Perda:     0.0003 | Acuracia: 0.6118
# Epoch 55, CIFAR-10 Batch 3:  Perda:     0.0001 | Acuracia: 0.6138
# Epoch 55, CIFAR-10 Batch 4:  Perda:     0.0005 | Acuracia: 0.6014
# Epoch 55, CIFAR-10 Batch 5:  Perda:     0.0008 | Acuracia: 0.6106
# Epoch 56, CIFAR-10 Batch 1:  Perda:     0.0004 | Acuracia: 0.6160
# Epoch 56, CIFAR-10 Batch 2:  Perda:     0.0001 | Acuracia: 0.6160
# Epoch 56, CIFAR-10 Batch 3:  Perda:     0.0001 | Acuracia: 0.6112
# Epoch 56, CIFAR-10 Batch 4:  Perda:     0.0002 | Acuracia: 0.6056
# Epoch 56, CIFAR-10 Batch 5:  Perda:     0.0017 | Acuracia: 0.6156
# Epoch 57, CIFAR-10 Batch 1:  Perda:     0.0003 | Acuracia: 0.6102
# Epoch 57, CIFAR-10 Batch 2:  Perda:     0.0001 | Acuracia: 0.6122
# Epoch 57, CIFAR-10 Batch 3:  Perda:     0.0014 | Acuracia: 0.6108
# Epoch 57, CIFAR-10 Batch 4:  Perda:     0.0001 | Acuracia: 0.6032
# Epoch 57, CIFAR-10 Batch 5:  Perda:     0.0011 | Acuracia: 0.6068
# Epoch 58, CIFAR-10 Batch 1:  Perda:     0.0002 | Acuracia: 0.6178
# Epoch 58, CIFAR-10 Batch 2:  Perda:     0.0001 | Acuracia: 0.6112
# Epoch 58, CIFAR-10 Batch 3:  Perda:     0.0002 | Acuracia: 0.6006
# Epoch 58, CIFAR-10 Batch 4:  Perda:     0.0001 | Acuracia: 0.6034
# Epoch 58, CIFAR-10 Batch 5:  Perda:     0.0003 | Acuracia: 0.6016
# Epoch 59, CIFAR-10 Batch 1:  Perda:     0.0003 | Acuracia: 0.6100
# Epoch 59, CIFAR-10 Batch 2:  Perda:     0.0001 | Acuracia: 0.6040
# Epoch 59, CIFAR-10 Batch 3:  Perda:     0.0001 | Acuracia: 0.6140
# Epoch 59, CIFAR-10 Batch 4:  Perda:     0.0001 | Acuracia: 0.6078
# Epoch 59, CIFAR-10 Batch 5:  Perda:     0.0002 | Acuracia: 0.6078
# Epoch 60, CIFAR-10 Batch 1:  Perda:     0.0004 | Acuracia: 0.6086
# Epoch 60, CIFAR-10 Batch 2:  Perda:     0.0002 | Acuracia: 0.6114
# Epoch 60, CIFAR-10 Batch 3:  Perda:     0.0000 | Acuracia: 0.6144
# Epoch 60, CIFAR-10 Batch 4:  Perda:     0.0003 | Acuracia: 0.6046
# Epoch 60, CIFAR-10 Batch 5:  Perda:     0.0002 | Acuracia: 0.6082
# Epoch 61, CIFAR-10 Batch 1:  Perda:     0.0013 | Acuracia: 0.6084
# Epoch 61, CIFAR-10 Batch 2:  Perda:     0.0000 | Acuracia: 0.6114
# Epoch 61, CIFAR-10 Batch 3:  Perda:     0.0001 | Acuracia: 0.6116
# Epoch 61, CIFAR-10 Batch 4:  Perda:     0.0003 | Acuracia: 0.5992
# Epoch 61, CIFAR-10 Batch 5:  Perda:     0.0000 | Acuracia: 0.6126
# Epoch 62, CIFAR-10 Batch 1:  Perda:     0.0001 | Acuracia: 0.6116
# Epoch 62, CIFAR-10 Batch 2:  Perda:     0.0002 | Acuracia: 0.6084
# Epoch 62, CIFAR-10 Batch 3:  Perda:     0.0002 | Acuracia: 0.6086
# Epoch 62, CIFAR-10 Batch 4:  Perda:     0.0006 | Acuracia: 0.6098
# Epoch 62, CIFAR-10 Batch 5:  Perda:     0.0002 | Acuracia: 0.6128
# Epoch 63, CIFAR-10 Batch 1:  Perda:     0.0001 | Acuracia: 0.6082
# Epoch 63, CIFAR-10 Batch 2:  Perda:     0.0001 | Acuracia: 0.6118
# Epoch 63, CIFAR-10 Batch 3:  Perda:     0.0002 | Acuracia: 0.6114
# Epoch 63, CIFAR-10 Batch 4:  Perda:     0.0000 | Acuracia: 0.6094
# Epoch 63, CIFAR-10 Batch 5:  Perda:     0.0003 | Acuracia: 0.6134
# Epoch 64, CIFAR-10 Batch 1:  Perda:     0.0000 | Acuracia: 0.6110
# Epoch 64, CIFAR-10 Batch 2:  Perda:     0.0003 | Acuracia: 0.6192
# Epoch 64, CIFAR-10 Batch 3:  Perda:     0.0000 | Acuracia: 0.6090
# Epoch 64, CIFAR-10 Batch 4:  Perda:     0.0002 | Acuracia: 0.6100
# Epoch 64, CIFAR-10 Batch 5:  Perda:     0.0011 | Acuracia: 0.6082
# Epoch 65, CIFAR-10 Batch 1:  Perda:     0.0001 | Acuracia: 0.6102
# Epoch 65, CIFAR-10 Batch 2:  Perda:     0.0002 | Acuracia: 0.6056
# Epoch 65, CIFAR-10 Batch 3:  Perda:     0.0001 | Acuracia: 0.6080
# Epoch 65, CIFAR-10 Batch 4:  Perda:     0.0002 | Acuracia: 0.6028
# Epoch 65, CIFAR-10 Batch 5:  Perda:     0.0003 | Acuracia: 0.6094
# Epoch 66, CIFAR-10 Batch 1:  Perda:     0.0000 | Acuracia: 0.6018
# Epoch 66, CIFAR-10 Batch 2:  Perda:     0.0008 | Acuracia: 0.6046
# Epoch 66, CIFAR-10 Batch 3:  Perda:     0.0001 | Acuracia: 0.6094
# Epoch 66, CIFAR-10 Batch 4:  Perda:     0.0001 | Acuracia: 0.6126
# Epoch 66, CIFAR-10 Batch 5:  Perda:     0.0001 | Acuracia: 0.6124
# Epoch 67, CIFAR-10 Batch 1:  Perda:     0.0000 | Acuracia: 0.6072
# Epoch 67, CIFAR-10 Batch 2:  Perda:     0.0001 | Acuracia: 0.6078
# Epoch 67, CIFAR-10 Batch 3:  Perda:     0.0002 | Acuracia: 0.6086
# Epoch 67, CIFAR-10 Batch 4:  Perda:     0.0001 | Acuracia: 0.6148
# Epoch 67, CIFAR-10 Batch 5:  Perda:     0.0007 | Acuracia: 0.6136
# Epoch 68, CIFAR-10 Batch 1:  Perda:     0.0002 | Acuracia: 0.6050
# Epoch 68, CIFAR-10 Batch 2:  Perda:     0.0116 | Acuracia: 0.6174
# Epoch 68, CIFAR-10 Batch 3:  Perda:     0.0001 | Acuracia: 0.6082
# Epoch 68, CIFAR-10 Batch 4:  Perda:     0.0001 | Acuracia: 0.6064
# Epoch 68, CIFAR-10 Batch 5:  Perda:     0.0003 | Acuracia: 0.6080
# Epoch 69, CIFAR-10 Batch 1:  Perda:     0.0000 | Acuracia: 0.6138
# Epoch 69, CIFAR-10 Batch 2:  Perda:     0.0000 | Acuracia: 0.6130
# Epoch 69, CIFAR-10 Batch 3:  Perda:     0.0000 | Acuracia: 0.6106
# Epoch 69, CIFAR-10 Batch 4:  Perda:     0.0002 | Acuracia: 0.6032
# Epoch 69, CIFAR-10 Batch 5:  Perda:     0.0003 | Acuracia: 0.6026
# Epoch 70, CIFAR-10 Batch 1:  Perda:     0.0001 | Acuracia: 0.6102
# Epoch 70, CIFAR-10 Batch 2:  Perda:     0.0000 | Acuracia: 0.6106
# Epoch 70, CIFAR-10 Batch 3:  Perda:     0.0001 | Acuracia: 0.6102
# Epoch 70, CIFAR-10 Batch 4:  Perda:     0.0002 | Acuracia: 0.6066
# Epoch 70, CIFAR-10 Batch 5:  Perda:     0.0004 | Acuracia: 0.6122
# Epoch 71, CIFAR-10 Batch 1:  Perda:     0.0001 | Acuracia: 0.6110
# Epoch 71, CIFAR-10 Batch 2:  Perda:     0.0000 | Acuracia: 0.6046
# Epoch 71, CIFAR-10 Batch 3:  Perda:     0.0001 | Acuracia: 0.6140
# Epoch 71, CIFAR-10 Batch 4:  Perda:     0.0000 | Acuracia: 0.6046
# Epoch 71, CIFAR-10 Batch 5:  Perda:     0.0003 | Acuracia: 0.6074
# Epoch 72, CIFAR-10 Batch 1:  Perda:     0.0000 | Acuracia: 0.6064
# Epoch 72, CIFAR-10 Batch 2:  Perda:     0.0000 | Acuracia: 0.6010
# Epoch 72, CIFAR-10 Batch 3:  Perda:     0.0001 | Acuracia: 0.6108
# Epoch 72, CIFAR-10 Batch 4:  Perda:     0.0000 | Acuracia: 0.6082
# Epoch 72, CIFAR-10 Batch 5:  Perda:     0.0001 | Acuracia: 0.6142
# Epoch 73, CIFAR-10 Batch 1:  Perda:     0.0032 | Acuracia: 0.6062
# Epoch 73, CIFAR-10 Batch 2:  Perda:     0.0000 | Acuracia: 0.6070
# Epoch 73, CIFAR-10 Batch 3:  Perda:     0.0001 | Acuracia: 0.6034
# Epoch 73, CIFAR-10 Batch 4:  Perda:     0.0001 | Acuracia: 0.6106
# Epoch 73, CIFAR-10 Batch 5:  Perda:     0.0009 | Acuracia: 0.6154
# Epoch 74, CIFAR-10 Batch 1:  Perda:     0.0000 | Acuracia: 0.6058
# Epoch 74, CIFAR-10 Batch 2:  Perda:     0.0000 | Acuracia: 0.6062
# Epoch 74, CIFAR-10 Batch 3:  Perda:     0.0001 | Acuracia: 0.6120
# Epoch 74, CIFAR-10 Batch 4:  Perda:     0.0001 | Acuracia: 0.5990
# Epoch 74, CIFAR-10 Batch 5:  Perda:     0.0001 | Acuracia: 0.6098
# Epoch 75, CIFAR-10 Batch 1:  Perda:     0.0000 | Acuracia: 0.6162
# Epoch 75, CIFAR-10 Batch 2:  Perda:     0.0001 | Acuracia: 0.6072
# Epoch 75, CIFAR-10 Batch 3:  Perda:     0.0002 | Acuracia: 0.6040
# Epoch 75, CIFAR-10 Batch 4:  Perda:     0.0003 | Acuracia: 0.6116
# Epoch 75, CIFAR-10 Batch 5:  Perda:     0.0001 | Acuracia: 0.6120

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.59951171875

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
